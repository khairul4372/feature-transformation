# %%
import pandas as pd
import numpy as np
df = pd.read_csv('house_price.csv')

# %%
df.head()
# Out:
#    Price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110

# %% [markdown]
# # Normalization / MinMaxScalar

# %%
min_price = df.Price.min()

# %%
min_price
# Out:
# 100

# %%
max_price = df.Price.max()

# %%
max_price
# Out:
# 150

# %%
df['Norm_manual'] = (df.Price - min_price) / (max_price - min_price)

# %%
df
# Out:
#    Price  Norm_manual
# 0    110          0.2
# 1    105          0.1
# 2    115          0.3
# 3    120          0.4
# 4    110          0.2
# 5    130          0.6
# 6    150          1.0
# 7    100          0.0
# 8    105          0.1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()

# %%
df['Norm_sklearn'] = mms.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn
# 0    110          0.2           0.2
# 1    105          0.1           0.1
# 2    115          0.3           0.3
# 3    120          0.4           0.4
# 4    110          0.2           0.2
# 5    130          0.6           0.6
# 6    150          1.0           1.0
# 7    100          0.0           0.0
# 8    105          0.1           0.1

# %% [markdown]
# # Standardization

# %%
mean_price = df.Price.mean()

# %%
mean_price
# Out:
# 116.11111111111111

# %%
std_price = df.Price.std(ddof = 0)

# %%
std_price
# Out:
# 14.677605348469895

# %%
df['Stand_manual'] = (df.Price - mean_price) / std_price

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn  Stand_manual
# 0    110          0.2           0.2     -0.416356
# 1    105          0.1           0.1     -0.757011
# 2    115          0.3           0.3     -0.075701
# 3    120          0.4           0.4      0.264954
# 4    110          0.2           0.2     -0.416356
# 5    130          0.6           0.6      0.946264
# 6    150          1.0           1.0      2.308884
# 7    100          0.0           0.0     -1.097666
# 8    105          0.1           0.1     -0.757011

# %%
from sklearn.preprocessing import StandardScaler

# %%
stds = StandardScaler()

# %%
df['Stand_sklearn'] = stds.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn  Stand_manual  Stand_sklearn
# 0    110          0.2           0.2     -0.416356      -0.416356
# 1    105          0.1           0.1     -0.757011      -0.757011
# 2    115          0.3           0.3     -0.075701      -0.075701
# 3    120          0.4           0.4      0.264954       0.264954
# 4    110          0.2           0.2     -0.416356      -0.416356
# 5    130          0.6           0.6      0.946264       0.946264
# 6    150          1.0           1.0      2.308884       2.308884
# 7    100          0.0           0.0     -1.097666      -1.097666
# 8    105          0.1           0.1     -0.757011      -0.757011

# %% [markdown]
# # Log Transformation

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
fc = FunctionTransformer(np.log1p)

# %%
df['fc_manual'] = np.log1p(df[['Price']])

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn  Stand_manual  Stand_sklearn  fc_manual  \
# 0    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 1    105          0.1           0.1     -0.757011      -0.757011   4.663439
# 2    115          0.3           0.3     -0.075701      -0.075701   4.753590
# 3    120          0.4           0.4      0.264954       0.264954   4.795791
# 4    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 5    130          0.6           0.6      0.946264       0.946264   4.875197
# 6    150          1.0           1.0      2.308884       2.308884   5.017280
# 7    100          0.0           0.0     -1.097666      -1.097666   4.615121
# 8    105          0.1           0.1     -0.757011      -0.757011   4.663439
#
#    fc_sklearn
# 0    4.709530
# 1    4.663439
# 2    4.753590
# 3    4.795791
# 4    4.709530
# 5    4.875197
# 6    5.017280
# 7    4.615121
# 8    4.663439

# %%
df['fc_sklearn'] = fc.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn  Stand_manual  Stand_sklearn  fc_manual  \
# 0    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 1    105          0.1           0.1     -0.757011      -0.757011   4.663439
# 2    115          0.3           0.3     -0.075701      -0.075701   4.753590
# 3    120          0.4           0.4      0.264954       0.264954   4.795791
# 4    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 5    130          0.6           0.6      0.946264       0.946264   4.875197
# 6    150          1.0           1.0      2.308884       2.308884   5.017280
# 7    100          0.0           0.0     -1.097666      -1.097666   4.615121
# 8    105          0.1           0.1     -0.757011      -0.757011   4.663439
#
#    fc_sklearn
# 0    4.709530
# 1    4.663439
# 2    4.753590
# 3    4.795791
# 4    4.709530
# 5    4.875197
# 6    5.017280
# 7    4.615121
# 8    4.663439

# %% [markdown]
# # Robust Scaler

# %%
q75, q25 = np.percentile(df.Price, [75 ,25])
iqr = q75 - q25

# %%
price_med = np.median(df.Price)

# %%
df['Robust_manual'] = (df.Price - price_med) / iqr

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn  Stand_manual  Stand_sklearn  fc_manual  \
# 0    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 1    105          0.1           0.1     -0.757011      -0.757011   4.663439
# 2    115          0.3           0.3     -0.075701      -0.075701   4.753590
# 3    120          0.4           0.4      0.264954       0.264954   4.795791
# 4    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 5    130          0.6           0.6      0.946264       0.946264   4.875197
# 6    150          1.0           1.0      2.308884       2.308884   5.017280
# 7    100          0.0           0.0     -1.097666      -1.097666   4.615121
# 8    105          0.1           0.1     -0.757011      -0.757011   4.663439
#
#    fc_sklearn  Robust_sklearn  Robust_manual
# 0    4.709530        0.000000       0.000000
# 1    4.663439       -0.333333      -0.333333
# 2    4.753590        0.333333       0.333333
# 3    4.795791        0.666667       0.666667
# 4    4.709530        0.000000       0.000000
# 5    4.875197        1.333333       1.333333
# 6    5.017280        2.666667       2.666667
# 7    4.615121       -0.666667      -0.666667
# 8    4.663439       -0.333333      -0.333333

# %%
from sklearn.preprocessing import RobustScaler

# %%
rb = RobustScaler(quantile_range=(25.0, 75.0),with_centering=True)

# %%
df['Robust_sklearn'] = rb.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn  Stand_manual  Stand_sklearn  fc_manual  \
# 0    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 1    105          0.1           0.1     -0.757011      -0.757011   4.663439
# 2    115          0.3           0.3     -0.075701      -0.075701   4.753590
# 3    120          0.4           0.4      0.264954       0.264954   4.795791
# 4    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 5    130          0.6           0.6      0.946264       0.946264   4.875197
# 6    150          1.0           1.0      2.308884       2.308884   5.017280
# 7    100          0.0           0.0     -1.097666      -1.097666   4.615121
# 8    105          0.1           0.1     -0.757011      -0.757011   4.663439
#
#    fc_sklearn  Robust_manual  Robust_sklearn
# 0    4.709530       0.000000        0.000000
# 1    4.663439      -0.333333       -0.333333
# 2    4.753590       0.333333        0.333333
# 3    4.795791       0.666667        0.666667
# 4    4.709530       0.000000        0.000000
# 5    4.875197       1.333333        1.333333
# 6    5.017280       2.666667        2.666667
# 7    4.615121      -0.666667       -0.666667
# 8    4.663439      -0.333333       -0.333333

# %% [markdown]
# # Max Absolute Scaler

# %%
df['Max_Absolute_manual'] = df.Price / df.Price.abs().max()

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn  Stand_manual  Stand_sklearn  fc_manual  \
# 0    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 1    105          0.1           0.1     -0.757011      -0.757011   4.663439
# 2    115          0.3           0.3     -0.075701      -0.075701   4.753590
# 3    120          0.4           0.4      0.264954       0.264954   4.795791
# 4    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 5    130          0.6           0.6      0.946264       0.946264   4.875197
# 6    150          1.0           1.0      2.308884       2.308884   5.017280
# 7    100          0.0           0.0     -1.097666      -1.097666   4.615121
# 8    105          0.1           0.1     -0.757011      -0.757011   4.663439
#
#    fc_sklearn  Robust_manual  Robust_sklearn  Max_Absolute_manual
# 0    4.709530       0.000000        0.000000             0.733333
# 1    4.663439      -0.333333       -0.333333             0.700000
# 2    4.753590       0.333333        0.333333             0.766667
# 3    4.795791       0.666667        0.666667             0.800000
# 4    4.709530       0.000000        0.000000             0.733333
# 5    4.875197       1.333333        1.333333             0.866667
# 6    5.017280       2.666667        2.666667             1.000000
# 7    4.615121      -0.666667       -0.666667             0.666667
# 8    4.663439      -0.333333       -0.333333             0.700000

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
mas = MaxAbsScaler()

# %%
df['Max_Absolute_sklearn'] = mas.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Norm_manual  Norm_sklearn  Stand_manual  Stand_sklearn  fc_manual  \
# 0    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 1    105          0.1           0.1     -0.757011      -0.757011   4.663439
# 2    115          0.3           0.3     -0.075701      -0.075701   4.753590
# 3    120          0.4           0.4      0.264954       0.264954   4.795791
# 4    110          0.2           0.2     -0.416356      -0.416356   4.709530
# 5    130          0.6           0.6      0.946264       0.946264   4.875197
# 6    150          1.0           1.0      2.308884       2.308884   5.017280
# 7    100          0.0           0.0     -1.097666      -1.097666   4.615121
# 8    105          0.1           0.1     -0.757011      -0.757011   4.663439
#
#    fc_sklearn  Robust_manual  Robust_sklearn  Max_Absolute_manual  \
# 0    4.709530       0.000000        0.000000             0.733333
# 1    4.663439      -0.333333       -0.333333             0.700000
# 2    4.753590       0.333333        0.333333             0.766667
# 3    4.795791       0.666667        0.666667             0.800000
# 4    4.709530       0.000000        0.000000             0.733333
# 5    4.875197       1.333333        1.333333             0.866667
# 6    5.017280       2.666667        2.666667             1.000000
# 7    4.615121      -0.666667       -0.666667             0.666667
# 8    4.663439      -0.333333       -0.333333             0.700000
#
#    Max_Absolute_sklearn
# 0              0.733333
# 1              0.700000
# 2              0.766667
# 3              0.800000
# 4              0.733333
# 5              0.866667
# 6              1.000000
# 7              0.666667
# 8              0.700000
